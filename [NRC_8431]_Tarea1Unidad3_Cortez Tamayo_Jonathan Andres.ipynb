# %%
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# load data
url = "https://raw.githubusercontent.com/JonathanC1/Datasets/master/TorNonTor/SelectedFeatures-10s-TOR-NonTOR.csv"
names = ['Source IP', 'Source Port', 'Destination IP', 'Destination Port', 'Protocol', 'Flow Duration', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min','Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min','Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min','Active Mean', 'Active Std', 'Active Max', 'Active Min','Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min','label']
dataframe = read_csv(url, names=names)
array = dataframe.values
X = array[:,18:28]
Y = array[:,28]
# feature extraction
model = LogisticRegression(solver='lbfgs')
rfe = RFE(model)
fit = rfe.fit(X, Y)
print("Num Features: %d" % fit.n_features_)
print("Selected Features: %s" % fit.support_)
print("Feature Ranking: %s" % fit.ranking_)
# Out:
# Num Features: 5
# Selected Features: [ True  True  True False  True  True False False False False]
# Feature Ranking: [1 1 1 6 1 1 4 5 3 2]

# %%
from pandas import read_csv
from sklearn.ensemble import ExtraTreesClassifier
# load data
url = "https://raw.githubusercontent.com/JonathanC1/Datasets/master/TorNonTor/SelectedFeatures-10s-TOR-NonTOR.csv"
names = ['Source IP', 'Source Port', 'Destination IP', 'Destination Port', 'Protocol', 'Flow Duration', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min','Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min','Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min','Active Mean', 'Active Std', 'Active Max', 'Active Min','Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min','label']
dataframe = read_csv(url, names=names)
array = dataframe.values
X = array[:,18:28]
Y = array[:,28]
# feature extraction
model = ExtraTreesClassifier(n_estimators=10)
model.fit(X, Y)
print(model.feature_importances_)
# Out:
# [0.66468927 0.28634981 0.00983974 0.         0.01007486 0.00923722
#  0.00653928 0.         0.00667957 0.00659025]

# %%
import matplotlib.pyplot as plt

#Relacion entre las etiquetas con una variable x
y_column=dataframe['label']
x_column=dataframe['Active Max']

#Regresion entre las etiquetas y la Inactividad Minima
fig, ax = plt.subplots()
ax.scatter(x_column,y_column)
plt.show()

# %%
import matplotlib.pyplot as plt

#Relacion entre las etiquetas con una variable x
y_column=dataframe['label']
x_column=dataframe['Active Min']

#Regresion entre las etiquetas y la Inactividad Minima
fig, ax = plt.subplots()
ax.scatter(x_column,y_column)
plt.show()

# %%
import matplotlib.pyplot as plt

#Relacion entre las etiquetas con una variable x
y_column=dataframe['label']
x_column=dataframe['Bwd IAT Max']

#Regresion entre las etiquetas y la Inactividad Minima
fig, ax = plt.subplots()
ax.scatter(x_column,y_column)
plt.show()

# %%
import matplotlib.pyplot as plt

#Relacion entre las etiquetas con una variable x
y_column=dataframe['label']
x_column=dataframe['Bwd IAT Min']

#Regresion entre las etiquetas y la Inactividad Minima
fig, ax = plt.subplots()
ax.scatter(x_column,y_column)
plt.show()

# %%
import matplotlib.pyplot as plt

#Relacion entre las etiquetas con una variable x
y_column=dataframe['label']
x_column=dataframe['Active Mean']

#Regresion entre las etiquetas y la Inactividad Minima
fig, ax = plt.subplots()
ax.scatter(x_column,y_column)
plt.show()
